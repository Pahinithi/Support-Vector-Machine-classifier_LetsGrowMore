# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/irisdata/iris.names
# /kaggle/input/irisdata/bezdekIris.data
# /kaggle/input/irisdata/Index
# /kaggle/input/irisdata/iris.data

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the iris-flower-dataset

# %%
df = pd.read_csv("/kaggle/input/irisdata/bezdekIris.data")

# %% [markdown]
# # Explore the dataset

# %%
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
# Assuming df is your existing DataFrame
data = [
    [5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
    [4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
    [4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
    [4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
    [5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
    # Add more rows as needed
]

# Define column names
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Create DataFrame with explicit column names
df = pd.DataFrame(data, columns=columns)

# Print the updated DataFrame
print(df)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Display descriptive statistics of numerical columns

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      5.000000     5.000000      5.000000          5.0
# mean       4.860000     3.280000      1.400000          0.2
# std        0.207364     0.258844      0.070711          0.0
# min        4.600000     3.000000      1.300000          0.2
# 25%        4.700000     3.100000      1.400000          0.2
# 50%        4.900000     3.200000      1.400000          0.2
# 75%        5.000000     3.500000      1.400000          0.2
# max        5.100000     3.600000      1.500000          0.2

# %% [markdown]
# Display descriptive statistics of all columns, including categorical ones

# %%
df.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width      species
# count       5.000000     5.000000      5.000000          5.0            5
# unique           NaN          NaN           NaN          NaN            1
# top              NaN          NaN           NaN          NaN  Iris-setosa
# freq             NaN          NaN           NaN          NaN            5
# mean        4.860000     3.280000      1.400000          0.2          NaN
# std         0.207364     0.258844      0.070711          0.0          NaN
# min         4.600000     3.000000      1.300000          0.2          NaN
# 25%         4.700000     3.100000      1.400000          0.2          NaN
# 50%         4.900000     3.200000      1.400000          0.2          NaN
# 75%         5.000000     3.500000      1.400000          0.2          NaN
# max         5.100000     3.600000      1.500000          0.2          NaN

# %% [markdown]
# Display information about the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  5 non-null      float64
#  1   sepal_width   5 non-null      float64
#  2   petal_length  5 non-null      float64
#  3   petal_width   5 non-null      float64
#  4   species       5 non-null      object
# dtypes: float64(4), object(1)
# memory usage: 328.0+ bytes

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa    5
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (5, 5)

# %% [markdown]
# check column names

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # Missing values

# %% [markdown]
# Display the count of missing values for each column

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
#  Assuming 'df' is a pandas DataFrame, this line retrieves the unique values in the 'species' column
#  The .unique() method returns an array of unique values present in the specified column

# %%
df.species.unique()
# Out:
# array(['Iris-setosa'], dtype=object)

# %% [markdown]
# Access the 'sepal_length' column in the DataFrame 'df' and retrieve unique values

# %%
df.sepal_length.unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. ])

# %%
df.sepal_width.unique()
# Out:
# array([3.5, 3. , 3.2, 3.1, 3.6])

# %%
df.petal_length.unique()
# Out:
# array([1.4, 1.3, 1.5])

# %%
df.petal_width.unique()
# Out:
# array([0.2])

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# Create a countplot using Seaborn
#
#  x='species': Specifies the categorical variable to be plotted on the x-axis
#
# data=df: Specifies the DataFrame containing the data
#
#  palette='turbo': Specifies the color palette to be used for the plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
colors = ['red', 'purple', 'gray']
sns.countplot(x='species', data=df, palette=colors)

plt.show()

# %% [markdown]
# Histograms

# %%
df['sepal_length'].hist(color='green')
# Out:
# <Axes: >

# %%
df['sepal_width'].hist(color='brown')
# Out:
# <Axes: >

# %%
df['petal_length'].hist(color='pink')
# Out:
# <Axes: >

# %%
df['petal_width'].hist(color='red')
# Out:
# <Axes: >

# %% [markdown]
# The Relationship between Sepal Length and Species

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='species',y='sepal_length',data=df.sort_values('sepal_length',ascending=False))
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# Correlation between Sepal Width and Species

# %%
df.plot(kind='scatter', x='sepal_width',y='sepal_length' , c='red')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# The connection between the width and length of a flower's sepal.

# %%
sns.jointplot(x='sepal_width', y='sepal_length', data=df, size=5, color='red')

# %% [markdown]
#  Assuming 'df' is a pandas DataFrame containing the data
#
# 'species' is a column in the DataFrame representing different species
#
#  Create a pair plot using Seaborn

# %%
sns.pairplot(df,hue='species',size=3)

# %% [markdown]
# Create violin plots for each feature

# %%
plt.figure(figsize=(14, 8))
for i, column in enumerate(df.columns[:-1]):
    plt.subplot(2, 2, i + 1)
    sns.violinplot(x='species', y=column, data=df, inner='quartile')
    plt.title(f'{column} distribution by species')
plt.show()

# %% [markdown]
# Create Swarm plots for each feature

# %%
plt.figure(figsize=(12, 8))
for i, column in enumerate(df.columns[:-1]):
    plt.subplot(2, 2, i + 1)
    sns.swarmplot(x='species', y=column, data=df)
    plt.title(f'{column} distribution by class')
plt.show()

# %% [markdown]
# Create boxplots to show any unusual data points

# %%
# Set the overall figure size
plt.figure(figsize=(15, 15))

# Subplot 1
plt.subplot(4, 2, 1)
fig = df.boxplot(column='sepal_length', color='red')
fig.set_title('Boxplot of Sepal Length')
fig.set_ylabel('sepal_length')

# Subplot 2
plt.subplot(4, 2, 2)
fig = df.boxplot(column='sepal_width', color='red')
fig.set_title('Boxplot of Sepal Width')
fig.set_ylabel('sepal_width')

# Subplot 3
plt.subplot(4, 2, 3)
fig = df.boxplot(column='petal_length', color='red')
fig.set_title('Boxplot of Petal Length')
fig.set_ylabel('petal_length')

# Subplot 4
plt.subplot(4, 2, 4)
fig = df.boxplot(column='petal_width', color='red')
fig.set_title('Boxplot of Petal Width')
fig.set_ylabel('petal_width')

# Display the plot
plt.show()

# %% [markdown]
# Make a histogram chart to see how things are spread out

# %%
plt.figure(figsize=(24, 20))

# Subplot 1
plt.subplot(4, 2, 1)
fig = df['sepal_length'].hist(bins=10, color='green')  # Set the color to green
fig.set_xlabel('IP Mean')
fig.set_title('Sepal Length')

# Subplot 2
plt.subplot(4, 2, 2)
fig = df['sepal_width'].hist(bins=10, color='green')
fig.set_xlabel('Sepal Width')
fig.set_title('Sepal Width')

# Subplot 3
plt.subplot(4, 2, 3)
fig = df['petal_length'].hist(bins=10, color='green')
fig.set_xlabel('Petal Length')
fig.set_title('Petal Length')

# Subplot 4
plt.subplot(4, 2, 4)
fig = df['petal_width'].hist(bins=10, color='green')
fig.set_xlabel('Petal Width')
fig.set_title('Petal Width')

plt.show()

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Create a histogram

# %%
import plotly.express as px

fig1 = px.histogram(df, x="species", color="sepal_length")  
fig1.show()
# Out:
# <div>                            <div id="bb2c9676-ec5f-41d2-a495-6deea2239d4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb2c9676-ec5f-41d2-a495-6deea2239d4b")) {                    Plotly.newPlot(                        "bb2c9676-ec5f-41d2-a495-6deea2239d4b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sepal_length=5.1\u003cbr\u003especies=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5.1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"5.1","offsetgroup":"5.1","orientation":"v","showlegend":true,"x":["Iris-setosa"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sepal_length=4.9\u003cbr\u003especies=%{
# ...

# %%
fig2 = px.histogram(df, x="species", color="sepal_width")  
fig2.show()
# Out:
# <div>                            <div id="fd72099d-6cfa-42aa-9878-af1cd754575e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd72099d-6cfa-42aa-9878-af1cd754575e")) {                    Plotly.newPlot(                        "fd72099d-6cfa-42aa-9878-af1cd754575e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sepal_width=3.5\u003cbr\u003especies=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3.5","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"3.5","offsetgroup":"3.5","orientation":"v","showlegend":true,"x":["Iris-setosa"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sepal_width=3.0\u003cbr\u003especies=%{x}
# ...

# %%
fig3 = px.histogram(df, x="species", color="petal_width")  
fig3.show()
# Out:
# <div>                            <div id="86f187e6-bde9-46d2-8cf1-3587147149ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86f187e6-bde9-46d2-8cf1-3587147149ab")) {                    Plotly.newPlot(                        "86f187e6-bde9-46d2-8cf1-3587147149ab",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"petal_width=0.2\u003cbr\u003especies=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.2","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0.2","offsetgroup":"0.2","orientation":"v","showlegend":true,"x":["Iris-setosa","Iris-setosa","Iris-setosa","Iris-setosa","Iris-setosa"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"dat
# ...

# %%
fig4= px.histogram(df, x="species", color="petal_length")  
fig4.show()
# Out:
# <div>                            <div id="762fb10e-cd8b-4ddd-8b4b-0c7991f0e2a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("762fb10e-cd8b-4ddd-8b4b-0c7991f0e2a3")) {                    Plotly.newPlot(                        "762fb10e-cd8b-4ddd-8b4b-0c7991f0e2a3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"petal_length=1.4\u003cbr\u003especies=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1.4","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1.4","offsetgroup":"1.4","orientation":"v","showlegend":true,"x":["Iris-setosa","Iris-setosa","Iris-setosa"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"petal_length
# ...

# %% [markdown]
#  create a scatter plot with x and y variables, distinguishing species.

# %%
def Scatterplot(x, y, c=None):
    global df
    
    plt.figure(figsize=(15, 6))
    for species in df['species'].unique():
        plt.scatter(ds[x][ds['species'] == species], ds[y][ds['species'] == species], label=species, edgecolor="k", alpha=0.7)
    plt.xticks(rotation=0)
    
    plt.title("Scatter plot X:{} / Y:{}".format(x, y))
    plt.xlabel(x)
    plt.ylabel(y)
    plt.legend()
    plt.show()

# %% [markdown]
# This code defines a function Scatterplot for creating scatter plots and then generates combinations of two columns from a list of column names. It iterates through these combinations, calling the Scatterplot function for each pair of columns.

# %%
from itertools import combinations
import matplotlib.pyplot as plt

def Scatterplot(x, y):
    plt.figure(figsize=(15, 6))
    for species in df['species'].unique():
        plt.scatter(df[x][df['species'] == species], df[y][df['species'] == species], label=species, edgecolor="k", alpha=0.7)
    plt.xticks(rotation=0)
    plt.title("Scatter plot X:{} / Y:{}".format(x, y))
    plt.xlabel(x)
    plt.ylabel(y)
    plt.legend()
    plt.show()

comb = combinations(["species", "petal_length", "petal_width", "sepal_length", "sepal_width"], 2)
comb_list = [list(i) for i in comb]

for col in comb_list:
    Scatterplot(col[0], col[1])

# %% [markdown]
# # Correlation Matrix

# %%
df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Compute the correlation matrix

# %%
# Assuming 'species' is a non-numeric column
encoded_df = pd.get_dummies(df, columns=['species'])

# Compute the correlation matrix
correlation_matrix = encoded_df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                      sepal_length  sepal_width  petal_length  petal_width  \
# sepal_length             1.000000     0.680019     -0.170499          NaN
# sepal_width              0.680019     1.000000     -0.136590          NaN
# petal_length            -0.170499    -0.136590      1.000000          NaN
# petal_width                   NaN          NaN           NaN          NaN
# species_Iris-setosa           NaN          NaN           NaN          NaN
#
#                      species_Iris-setosa
# sepal_length                         NaN
# sepal_width                          NaN
# petal_length                         NaN
# petal_width                          NaN
# species_Iris-setosa                  NaN

# %%
# Assuming 'species' is a non-numeric column that causes the error
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000     0.680019     -0.170499          NaN
# sepal_width       0.680019     1.000000     -0.136590          NaN
# petal_length     -0.170499    -0.136590      1.000000          NaN
# petal_width            NaN          NaN           NaN          NaN

# %% [markdown]
# Displaying the correlation using Heatmap

# %%
# You can select only numeric columns using select_dtypes
numeric_df = df.select_dtypes(include='number')

# Calculate correlation matrix
corr = numeric_df.corr()

# Create a heatmap
fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(corr, annot=True, ax=ax, cmap='cividis')

# Show the plot
plt.show()

# %% [markdown]
# Get X and Y

# %%
X = df.drop(['species'], axis=1)

y = df['species']

# %% [markdown]
# Separate the information in X and y into two groups for practicing and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 10)

# %%
X_train.shape, X_test.shape
# Out:
# ((3, 4), (2, 4))

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# When working with SVM modeling on the Iris dataset, it's essential to use Standard Scaler and scale the features

# %%
cols = X_train.columns

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=[cols])

# %%
X_test = pd.DataFrame(X_test, columns=[cols])

# %%
X_train.head()
# Out:
#   sepal_length sepal_width  petal_length   petal_width
# 0     1.224745    0.508001  2.220446e-16 -2.775558e-17
# 1     0.000000    0.889001  2.220446e-16 -2.775558e-17
# 2    -1.224745   -1.397001  2.220446e-16 -2.775558e-17

# %% [markdown]
# The default values for the settings are C set to 1.0, kernel set to rbf, and gamma set to auto

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)

# %%
print("Unique classes in y_train:", np.unique(y_train))
# Out:
# Unique classes in y_train: [0 1 2]

# %%
# import SVC classifier
from sklearn.svm import SVC

# import metrics to compute accuracy
from sklearn.metrics import accuracy_score

# instantiate classifier with default hyperparameters
svc=SVC() 

# fit classifier to training set
svc.fit(X_train,y_train)

# make predictions on test set
y_pred=svc.predict(X_test)

# compute and print accuracy score
print('Model accuracy score with default hyperparameters: {0:0.2f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with default hyperparameters: 1.00

# %% [markdown]
# Check if the model works well on both the training and testing data to make sure it's not just memorizing the training data

# %%
y_pred_train = svc.predict(X_train)

y_pred_train
# Out:
# array([0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0, 0, 1, 2, 2, 1, 2, 1, 2,
#        1, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 1, 0, 1, 2, 0, 1, 2, 0, 2, 2,
#        1, 1, 2, 1, 0, 1, 2, 0, 0, 1, 2, 0, 2, 0, 0, 1, 1, 2, 2, 2, 2, 1,
#        0, 0, 2, 2, 0, 0, 0, 1, 2, 0, 2, 2, 0, 1, 1, 2, 1, 2, 0, 2, 1, 2,
#        1, 1, 1, 0, 1, 1, 0, 1, 2, 2, 0, 1, 2, 2, 0, 2, 0, 1, 2, 2, 1, 2,
#        1, 1, 2, 2, 0, 1, 1, 0, 1, 2])

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Out:
# Training-set accuracy score: 0.9750

# %% [markdown]
# # Balancing Act: Navigating Overfitting and Underfitting in Machine Learning Models

# %% [markdown]
# Overfitting happens when a model does really well on the training data but not so well on new, unseen data. This occurs when the model is too complicated and picks up on random or specific patterns in the training data that don't apply well to new data. On the other hand, underfitting occurs when a model doesn't perform well on either the training or test data, suggesting it's too simple to understand the underlying patterns.
#
# Ideally, you want the accuracy of the test set to be close to the accuracy of the training set. If the model generalizes well, both accuracies should be similar. If the test-set accuracy significantly drops compared to the train-set accuracy, it may mean overfitting. The scores here are similar and satisfactory.

# %% [markdown]
# # Compare how well the model performs with how well it would do by just guessing

# %% [markdown]
# While the model shows a perfect accuracy of 1.00, it's important to note that this alone doesn't guarantee perfection. To assess its performance, we should compare it to null accuracy, which is the accuracy achieved by always predicting the most common class. In our dataset, since all three classes have equal frequency, the null accuracy is not necessary to consider.
